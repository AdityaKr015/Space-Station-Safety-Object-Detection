# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaKr015/Space-Station-Safety-Object-Detection/blob/main/Space.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.4/112.6 GB disk)

# %%
import ultralytics
from ultralytics import YOLO
model = YOLO("yolov8m.pt")

# %%
dataset_path = "/content/drive/MyDrive/Dataset"

# %%
# from ultralytics.data.utils import IMG_FORMATS
# from PIL import Image
# import os, glob
# from tqdm import tqdm

# # --- Function to resize images ---
# def resize_images(input_dir, output_dir, size=(640, 640)):
#     os.makedirs(output_dir, exist_ok=True)
#     images = glob.glob(os.path.join(input_dir, "*"))
#     print(f"Resizing {len(images)} images from {input_dir} ...")
#     for img_path in tqdm(images):
#         if img_path.split(".")[-1].lower() in IMG_FORMATS:
#             try:
#                 img = Image.open(img_path)
#                 img = img.resize(size)
#                 img.save(os.path.join(output_dir, os.path.basename(img_path)))
#             except Exception as e:
#                 print(f"⚠️ Skipped {img_path}: {e}")

# # --- Train ---
# resize_images(
#     input_dir="/content/drive/MyDrive/dataset/train/images",
#     output_dir="/content/dataset_resized/train/images"
# )

# # --- Validation ---
# resize_images(
#     input_dir="/content/drive/MyDrive/dataset/val/images",
#     output_dir="/content/dataset_resized/val/images"
# )

# # --- Test ---
# resize_images(
#     input_dir="/content/drive/MyDrive/dataset/test/images",
#     output_dir="/content/dataset_resized/test/images"
#)

# %%
# # Zip the resized folders
# import shutil

# # Zip each folder separately
# shutil.make_archive('/content/train_resized', 'zip', '/content/dataset_resized/train/images')
# shutil.make_archive('/content/val_resized', 'zip', '/content/dataset_resized/val/images')
# shutil.make_archive('/content/test_resized', 'zip', '/content/dataset_resized/test/images')

# print("Zipping complete!")

# %%
model.train(
    data='/content/drive/MyDrive/Dataset/yolo_params.yaml',
    epochs=50,
    imgsz=640,
    batch=8,
    cache=True,
    project='/content/drive/MyDrive/Results',
    name='YOLOv8m_Final'
)
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls '/content/drive/MyDrive/Results/YOLOv8m_Final2'
# Out:
# args.yaml			 results.csv	      val_batch0_labels.jpg
# BoxF1_curve.png			 results.png	      val_batch0_pred.jpg
# BoxP_curve.png			 train_batch0.jpg     val_batch1_labels.jpg
# BoxPR_curve.png			 train_batch1.jpg     val_batch1_pred.jpg
# BoxR_curve.png			 train_batch2.jpg     val_batch2_labels.jpg
# confusion_matrix_normalized.png  train_batch8840.jpg  val_batch2_pred.jpg
# confusion_matrix.png		 train_batch8841.jpg  weights
# labels.jpg			 train_batch8842.jpg

# %%
from IPython.display import Image,display
resultData=('/content/drive/MyDrive/Results/YOLOv8m_Final2')
Image(filename=f'{resultData}/confusion_matrix.png')

# %%
resultData=('/content/drive/MyDrive/Results/YOLOv8m_Final2')
Image(filename=f'{resultData}/results.png')

# %%
import pandas as pd
resultData = '/content/drive/MyDrive/Results/YOLOv8m_Final2/'
df = pd.read_csv(f'{resultData}results.csv')
print(df.head(5))
# Out:
#    epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0      1   72.7528         0.96084         2.04817         1.21285
# 1      2  147.2770         1.11534         1.53264         1.31089
# 2      3  224.0610         1.15206         1.45904         1.30953
# 3      4  293.1440         1.13791         1.42715         1.30492
# 4      5  367.2740         1.09371         1.35173         1.27304
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0               0.63349            0.46250           0.50243
# 1               0.72215            0.45548           0.53391
# 2               0.67222            0.47974           0.53473
# 3               0.66763            0.54003           0.58310
# 4               0.76462            0.55108           0.61882
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 0              0.35359       0.94787       1.55165       1.23012  0.000302
# ...

# %%
import pandas as pd
df=pd.read_csv(f'{resultData}results.csv')
print(df.tail(1))
# Out:
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 49     50  3682.02         0.40056         0.31549         0.87549
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 49               0.94058            0.77638           0.84445
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 49              0.72241       0.44067       0.40685       0.87591  0.000027
#
#       lr/pg1    lr/pg2
# 49  0.000027  0.000027
